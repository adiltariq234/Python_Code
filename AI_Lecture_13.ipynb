# %% [markdown]
# <a href="https://colab.research.google.com/github/adiltariq234/Python_Code/blob/adiltariq234-patch-2/AI_Lecture_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
import openai

# %%
# !pip install google-generativeai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.1/155.1 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import google.generativeai as genai

# %%
# !pip uninstall -y google-generativeai
# !pip install -U google-genai
# Out:
# Found existing installation: google-generativeai 0.8.6
# Uninstalling google-generativeai-0.8.6:
#   Successfully uninstalled google-generativeai-0.8.6
# ...

# %%
import google.generativeai as genai

genai.configure(api_key="")

models = genai.list_models()
for m in models:
    print(m.name, "=>", m.supported_generation_methods)
# Out:
# models/embedding-gecko-001 => ['embedText', 'countTextTokens']
# models/gemini-2.5-flash => ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-pro => ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-exp => ['generateContent', 'countTokens', 'bidiGenerateContent']
# models/gemini-2.0-flash => ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-001 => ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-exp-image-generation => ['generateContent', 'countTokens', 'bidiGenerateContent']
# models/gemini-2.0-flash-lite-001 => ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite => ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# ...

# %%
from google import genai

client = genai.Client(api_key="")

response = client.models.generate_content(
    model="models/gemini-flash-latest",
    contents="Explain AI in simple words"
)

print(response.text)
# Out:
# Imagine you have a really smart helper.
#
# **That helper is what we call Artificial Intelligence, or AI.**
#
# Here's how it works:
#
# ---
#
# ### 1. The Goal: Being Smart
#
# The main goal of AI is to make computers **think and learn** just like a human. It's about giving a machine the ability to be intelligent.
#
# ### 2. How It Learns
#
# Instead of being told every single step (like a normal computer program), AI learns through **experience and data**.
#
# **Think of it like teaching a child:**
#
# * **If you want the AI to recognize a cat:** You don't describe the cat with code. You show the AI **thousands of pictures** of cats and thousands of pictures of things that are **not** cats.
# * **The AI studies these examples** and figures out the patterns on its own (whiskers, pointy ears, size, etc.).
# * **After enough practice,** when you show it a brand new picture, it can confidently say, "That's a cat!"
#
# ### 3. What It Does
#
# ...

# %%
# !pip install -U google-genai pillow requests

# %%
import io
from google import genai
import requests
import PIL
from PIL import Image

# %%
from google import genai
from PIL import Image
import io
import base64

# Initialize client
client = genai.Client(api_key="")

def generate_image_with_text_prompt(text_prompt):
    """
    Generate an image using Google Imagen model based on the provided text prompt.

    :param text_prompt: The prompt to generate image
    :return: PIL Image object
    """
    # Generate image using the official SDK
    result = client.models.generate_images(
        model="models/imagen-4.0-generate-001",
        prompt=text_prompt,
        number_of_images=1, # Moved out of config dictionary
        size="256x256"      # Moved out of config dictionary
    )

    # Decode the generated image
    image_base64 = result.generated_images[0].image.image_bytes
    image_bytes = base64.b64decode(image_base64)
    image = Image.open(io.BytesIO(image_bytes))
    return image

# %%
from google import genai
from PIL import Image
import io
import base64

# Initialize client
# client = genai.Client(api_key="YOUR_API_KEY")
client = genai.Client(api_key="")

def generate_image_with_text_prompt(text_prompt):
    """
    Generate an image using Google Imagen model based on the provided text prompt.

    :param text_prompt: The prompt to generate image
    :return: PIL Image object
    """
    # Correct usage with generate_images
    result = client.models.generate_images(
        model="models/gemini-2.5-flash-image",
        prompt=text_prompt
    )

    # Decode the generated image
    image_base64 = result.generated_images[0].image_bytes
    image_bytes = base64.b64decode(image_base64)
    image = Image.open(io.BytesIO(image_bytes))
    return image

# %%
prompt = "A futuristic AI robot teaching students in a classroom, digital art, colorful, high detail"
image = generate_image_with_text_prompt(prompt)
image.show()  # Colab / Jupyter me display

# %%
# !pip install transformers

# %%
import transformers
from transformers import pipeline
pipe=pipeline("text-classification", model="ProsusAI/finbert")
pipe("This movie is very boring")
# Out:
# Device set to use cuda:0
# [{'label': 'neutral', 'score': 0.890781044960022}]

# %%
import transformers
from transformers import pipeline
pipe=pipeline("text-classification",model="cardiffnlp/twitter-roberta-base-sentiment-latest")
pipe("I hate you")
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/501M [00:00<?, ?B/s]
# ...

# %%
import transformers
from transformers import pipeline
pipe=pipeline("text-classification",model="cardiffnlp/twitter-roberta-base-sentiment-latest")
pipe(["You are beautifull","This resturant awsome","This resturant is awful"])

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
import numpy as np
from scipy.special import softmax
# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
#model.save_pretrained(MODEL)
text = "you are beautifull"
text = preprocess(text)
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
# # TF
# model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
# model.save_pretrained(MODEL)
# text = "Covid cases are increasing fast!"
# encoded_input = tokenizer(text, return_tensors='tf')
# output = model(encoded_input)
# scores = output[0][0].numpy()
# scores = softmax(scores)
# Print labels and scores
ranking = np.argsort(scores)
ranking = ranking[::-1]
for i in range(scores.shape[0]):
    l = config.id2label[ranking[i]]
    s = scores[ranking[i]]
    print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 1) positive 0.956
# 2) neutral 0.0306
# 3) negative 0.0134

# %%
# !pip install -U diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 100.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 142.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.1.5
#     Uninstalling hf-xet-1.1.5:
#       Successfully uninstalled hf-xet-1.1.5
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.33.4
#     Uninstalling huggingface-hub-0.33.4:
#       Successfully uninstalled huggingface-hub-0.33.4
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.34.0
#     Uninstalling diffusers-0.34.0:
#       Successfully uninstalled diffusers-0.34.0
# ...
