# %% [markdown]
# <a href="https://colab.research.google.com/github/adiltariq234/Python_Code/blob/adiltariq234-patch-3/lecture3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
students=["ALi","Adil","Azeem","Hashim"]
for name in students:
  print(f"Welcome  {name}")
# Out:
# Welcome  ALi
# Welcome  Adil
# Welcome  Azeem
# Welcome  Hashim

# %%
number=(1,2,3,4,5,6,30,25,64)
for n in number:
  if n>10:

    print(f"{n} is bigger then 10")
# Out:
# 30 is bigger then 10
# 25 is bigger then 10
# 64 is bigger then 10

# %%
for i in range(10):
  if i==5:
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
