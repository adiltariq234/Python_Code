# %%
import time

def time_guard(worker):
    def wrapper():
        start = time.time()      # ghari dekhi
        worker()                 # worker ne kaam kia
        end = time.time()        # dubara ghari dekhi
        print("⏱ Kaam ka time:", round(end-start, 2), "seconds")
    return wrapper

# %%
with open("error_log.txt") as f:
    print(f.read())
# Out:
# [2025-12-24 10:31:09] ERROR in broken_machine: division by zero
